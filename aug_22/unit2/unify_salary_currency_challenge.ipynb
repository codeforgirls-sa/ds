# %%
#! pip install --user currencyconverter

# %%
import pandas as pd
file_path = '/Users/hananalaskar/Documents/Code for Girls/data-science/ds-master/' 
df = pd.read_csv(file_path+'data_set/ds_salaries.csv')

df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
from currency_converter import CurrencyConverter

# %%
salary_currency_df = df.drop_duplicates(subset='salary_currency', keep='first')
salary_currency_df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 7             7       2020               MI              FT
# 11           11       2020               MI              FT
# 16           16       2020               EN              FT
# 20           20       2020               MI              FT
# 27           27       2020               SE              FT
# 29           29       2020               SE              FT
# 52           52       2020               EN              FT
# 85           85       2021               MI              FT
# 95           95       2021               MI              FT
# 177         177       2021               MI              FT
# 205         205       2021               MI              FT
# 247         247       2021               MI              FT
# ...

# %%
salary_currency_df = salary_currency_df[['salary_currency', 'salary', 'salary_in_usd']]
salary_currency_df.reset_index(drop=True, inplace = True)
salary_currency_df
# Out:
#    salary_currency    salary  salary_in_usd
# 0              EUR     70000          79833
# 1              USD    260000         260000
# 2              GBP     85000         109024
# 3              HUF  11000000          35735
# 4              INR   3000000          40481
# 5              JPY   4450000          41689
# 6              CNY    299000          43331
# 7              MXN    720000          33511
# 8              CAD    157000         117104
# 9              DKK    300000          45896
# 10             PLN    110000          28476
# 11             SGD    120000          89294
# 12             CLP  30400000          40038
# 13             BRL     69600          12901
# 14             TRY    108000          12103
# 15             AUD    121000          87425
# 16             CHF    115000         122346

# %%
salary_currency_df = salary_currency_df[['salary','salary_currency']]

# %%
test_df = salary_currency_df.loc[salary_currency_df['salary_currency'] != 'CLP']
test_df.reset_index(drop=True, inplace = True)

# %%
[ CurrencyConverter().convert( test_df['salary'][i], test_df['salary_currency'][i], 'USD')
 for i in range(test_df.shape[0])]
# Out:
# [70916.99999999999,
#  260000.0,
#  101659.2293525995,
#  27718.19425444596,
#  37506.47876200113,
#  32165.34674657534,
#  44373.02610377054,
#  35222.09613945291,
#  120946.46794920537,
#  40831.598038557124,
#  23333.542713567836,
#  85898.39609976682,
#  12936.7507568113,
#  6173.779094371561,
#  82610.08154188287,
#  117552.71920088789]

# %%
df.loc[df['salary_currency'] == 'CLP']
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 177         177       2021               MI              FT  Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 177  30400000             CLP          40038                 CL           100
#
#     company_location company_size
# 177               CL            L
